# %%
#This is for building a sequential neural network
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from keras.models import Sequential #A layered neural network 
from keras.layers import Dense #Layers 

import warnings
warnings.filterwarnings("ignore")

#Define the model
model = Sequential()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 #This is for building a sequential neural network
#       2 import pandas as pd
# ----> 3 from sklearn.preprocessing import LabelEncoder
#       4 from keras.models import Sequential #A layered neural network
#       5 from keras.layers import Dense #Layers
#
# File c:\Users\benlu\Downloads\INST326_Github\health-rating-app-mlmodel\.venv\Lib\site-packages\sklearn\__init__.py:70
#      62 # `_distributor_init` allows distributors to run custom init code.
#      63 # For instance, for the Windows wheel, this is used to pre-load the
#      64 # vcomp shared library runtime for OpenMP embedded in the sklearn/.libs
#    (...)     67 # later is linked to the OpenMP runtime to make it possible to introspect
#      68 # it and importing it first would fail if the OpenMP dll cannot be found.
# ...

# %%
#Define Dataset
health_db = pd.read_csv("health_dataset.csv")

#Transform objects into numerics
columns = ["exercise_frequency", "part_time_job", "extracurricular_participation"]
for feature in columns:
    le = LabelEncoder()
    health_db[feature] = le.fit_transform(health_db[feature])

#Drop unused columns
health_db = health_db.drop(["student_id", "age", "gender", "attendance_percentage", 
                            "parental_education_level", "internet_quality", "exam_score"])

# %%
#Add the layers of the neural network after defining the model
#Layer format: (Dense(a, b, c, d))
#a: The dimension. Equals the number of inputs (columns used excluding target)
#b: Kernel_initializer. Sets the weights of the layer
#c: Activation.
model.add(Dense(7, kernel_intializer = "uniform", activation = "relu", input_dm = 5))
